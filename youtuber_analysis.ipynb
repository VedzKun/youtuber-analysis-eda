# %% [markdown]
# <a href="https://colab.research.google.com/github/VedzKun/youtuber-analysis-eda/blob/main/youtuber_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Youtuber Analysis EDA Project

# %% [markdown]
# ##Running Jovian

# %%
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('youtuber_analysis')
jovian.set_colab_id('1IyAEj7Mg5puZQUbNf6oyGs2PrsPLYqBK')

# %% [markdown]
# ##Downloading Data

# %%
pip install opendatasets --upgrade

# %%
import opendatasets as od

download_url = 'https://www.kaggle.com/datasets/nelgiriyewithana/global-youtube-statistics-2023'
od.download(download_url)
# Out:
# Skipping, found downloaded files in "./global-youtube-statistics-2023" (use force=True to force download)

# %%
data_filename=('./global-youtube-statistics-2023/youtuber-statistics.csv')

# %% [markdown]
# ## Displaying and Preparing data

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename, encoding='unicode_escape')

# %%
df.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.isnull()
# Out:
#       rank  Youtuber  subscribers  video views  category  Title  uploads  \
# 0    False     False        False        False     False  False    False
# 1    False     False        False        False     False  False    False
# 2    False     False        False        False     False  False    False
# 3    False     False        False        False     False  False    False
# 4    False     False        False        False     False  False    False
# ..     ...       ...          ...          ...       ...    ...      ...
# 990  False     False        False        False     False  False    False
# 991  False     False        False        False     False  False    False
# 992  False     False        False        False      True  False    False
# 993  False     False        False        False     False  False    False
# 994  False     False        False        False     False  False    False
#
#      Country  Abbreviation  channel_type  ...  subscribers_for_last_30_days  \
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# ###Cleaning data

# %%
df = df[['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'uploads', 'Country','highest_yearly_earnings', 'video_views_for_the_last_30_days', 'created_year']]

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'uploads',
#        'Country', 'highest_yearly_earnings',
#        'video_views_for_the_last_30_days', 'created_year'],
#       dtype='object')

# %% [markdown]
# Updated form of the dataframe. With lesser amount of data to deal with.

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category  uploads        Country  highest_yearly_earnings  \
# 0             Music    20082          India             1.084000e+08
# 1  Film & Animation        1  United States             5.800000e-01
# 2     Entertainment      741  United States             6.470000e+07
# 3         Education      966  United States             9.480000e+07
# 4             Shows   116536          India             8.750000e+07
#
#    video_views_for_the_last_30_days  created_year
# 0                      2.258000e+09        2006.0
# 1                      1.200000e+01        2006.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rank                              995 non-null    int64
#  1   Youtuber                          995 non-null    object
#  2   subscribers                       995 non-null    int64
#  3   video views                       995 non-null    float64
#  4   category                          949 non-null    object
#  5   uploads                           995 non-null    int64
#  6   Country                           873 non-null    object
#  7   highest_yearly_earnings           995 non-null    float64
#  8   video_views_for_the_last_30_days  939 non-null    float64
#  9   created_year                      990 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 77.9+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category  uploads         Country  highest_yearly_earnings  \
# 0               Music    20082           India             1.084000e+08
# ...

# %% [markdown]
# ##Representing Data and Analysis

# %% [markdown]
# ###Representing Number of youtubers by their subscriber counts.
#
# This helps us analyse how many youtubers are in a certain subscriber count range.

# %%
youtubers_by_subscribers = df.subscribers.value_counts()
youtubers_by_subscribers[:20].plot(kind='barh')
plt.ylabel("Subscriber Count")
# Out:
# Text(0, 0.5, 'Subscriber Count')

# %% [markdown]
# We can infer from above data that around 9 youtubers have crossed the 149 million subsribers according to our data set.

# %% [markdown]
# ###Representing Number of youtubers by their category.

# %%
import matplotlib.pyplot as plt

youtubers_by_category = df.category.value_counts()
youtubers_by_category.plot(kind='barh')
plt.ylabel("Category")
# Out:
# Text(0, 0.5, 'Category')

# %% [markdown]
# The above chart is helpful in many aspects. It can come in use for data anlysts as a good source of data and at the same time server to people as data that helps them understand what category is currently trending in the market.

# %% [markdown]
# ###Representing number of youtubers from countries.
#
# In order to keep the graph, I have only mentioned it for top 20 items in the data set.

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.histplot(df.Country[:15])
plt.title("Number of youtubers emerging from different countries")
# Out:
# Text(0.5, 1.0, 'Number of youtubers emerging from different countries')

# %%
high_subscriber_youtubers = df.subscribers[df.subscribers > 100000000]
low_subscriber_youtubers = df.subscribers[df.subscribers < 99999999]

# %%
len(high_subscriber_youtubers) / len(df.subscribers)
# Out:
# 0.009045226130653266

# %% [markdown]
# ##Summary and conclusions

# %% [markdown]
# ##Insights
#
# -Over 300 youtubers belong to the United States and over 150 belong to India.
#
# -The entertainment category seems to be the trending pattern in the youtube world right now.
#
# -Only 9% of the youtubers have actually crossed the 100 million subscriber mark.
#
# -T-series has the highest earning per year of all channels.
#
# -Most of the youtube market is dominated by companies rather than seperate youtubers.

# %% [markdown]
# ###Asking Simple Questions:
#
# 1) What is the right ategory to target for highest audience?
#
# 2) Which country has a higher number of famous youtubers?
#
# 3) Does one really need a company to excel in their youtube career?
#
# 4) Do music companies have the upper hand in the youtube algorithm?
